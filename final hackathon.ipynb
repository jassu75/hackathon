# %% [markdown]
# # World Happiness Dataset Analysis

# %% [markdown]
# ## About Dataset

# %% [markdown]
# ### Context

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness . The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# ### Content

# %% [markdown]
# The happiness scores and rankings use data from the Gallup World Poll . The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
df=pd.read_csv(r"C:\Users\tejas\Downloads\archive (2)\world-happiness-report-2021.csv")

# %%
df1=pd.read_csv(r"C:\Users\tejas\Downloads\archive (2)\world-happiness-report.csv")

# %%
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df1
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df1.head(20)
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008        3.724               7.370           0.451
# 1   Afghanistan  2009        4.402               7.540           0.552
# 2   Afghanistan  2010        4.758               7.647           0.539
# 3   Afghanistan  2011        3.832               7.620           0.521
# 4   Afghanistan  2012        3.783               7.705           0.521
# 5   Afghanistan  2013        3.572               7.725           0.484
# 6   Afghanistan  2014        3.131               7.718           0.526
# 7   Afghanistan  2015        3.983               7.702           0.529
# 8   Afghanistan  2016        4.220               7.697           0.559
# 9   Afghanistan  2017        2.662               7.697           0.491
# 10  Afghanistan  2018        2.694               7.692           0.508
# 11  Afghanistan  2019        2.375               7.697           0.420
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Insights in the dataset

# %% [markdown]
# ## shape

# %%
df.shape
# Out:
# (149, 20)

# %% [markdown]
# ## size

# %%
df.size
# Out:
# 2980

# %% [markdown]
# ## duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## null

# %%
df.isna().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
df1.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %% [markdown]
# # `subtracting dystopia score from ladder score

# %%
df['Ladder score'] = df['Ladder score'] - 2.43
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         5.412
# 1        Denmark      Western Europe         5.190
# 2    Switzerland      Western Europe         5.141
# 3        Iceland      Western Europe         5.124
# 4    Netherlands      Western Europe         5.034
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         1.082
# 145     Botswana  Sub-Saharan Africa         1.037
# 146       Rwanda  Sub-Saharan Africa         0.985
# 147     Zimbabwe  Sub-Saharan Africa         0.715
# 148  Afghanistan          South Asia         0.093
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# ## detail info of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       3.102839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        0.093000                        0.026000      2.596000
# 25%        2.422000                        0.043000      4.991000
# 50%        3.104000                        0.054000      5.625000
# 75%        3.825000                        0.070000      6.344000
# max        5.412000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df1.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %% [markdown]
# * There are 148 rows in dataset
# * there are 20 columns in dataset
# * there are no duplicate and null values in dataset

# %% [markdown]
# # Tasks

# %% [markdown]
# ## top 10 and bottom countries

# %% [markdown]
# ## group country names by taking mean of remaining columns

# %%
df2 = df1.groupby('Country name').mean()

# %%
df2 = df2.drop(columns=['year'])

# %%
df2
# Out:
#               Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan      3.594667            7.650833        0.508417
# Albania          5.019385            9.384385        0.716231
# Algeria          5.389875            9.328875        0.803571
# Angola           4.420250            8.990000        0.738250
# Argentina        6.310133           10.033800        0.904400
# ...                   ...                 ...             ...
# Venezuela        6.019867            9.480083        0.910133
# Vietnam          5.305857            8.655286        0.829231
# Yemen            3.912250            8.102700        0.739833
# Zambia           4.551714            8.066857        0.737714
# Zimbabwe         3.882600            7.850333        0.799400
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          52.266667                      0.518167
# ...

# %%
df2.isna().sum()
# Out:
# Life Ladder                         0
# Log GDP per capita                  5
# Social support                      1
# Healthy life expectancy at birth    4
# Freedom to make life choices        0
# Generosity                          5
# Perceptions of corruption           5
# Positive affect                     2
# Negative affect                     1
# dtype: int64

# %% [markdown]
# ## remove null

# %%
df2.dropna(inplace=True)
df2
# Out:
#               Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan      3.594667            7.650833        0.508417
# Albania          5.019385            9.384385        0.716231
# Algeria          5.389875            9.328875        0.803571
# Angola           4.420250            8.990000        0.738250
# Argentina        6.310133           10.033800        0.904400
# ...                   ...                 ...             ...
# Venezuela        6.019867            9.480083        0.910133
# Vietnam          5.305857            8.655286        0.829231
# Yemen            3.912250            8.102700        0.739833
# Zambia           4.551714            8.066857        0.737714
# Zimbabwe         3.882600            7.850333        0.799400
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          52.266667                      0.518167
# ...

# %% [markdown]
# ## m represents processed version of df1

# %%
m=df2
m.reset_index(inplace=True)

# %% [markdown]
# ## sort the dataset

# %%
df2_sorted = df2.sort_values(by='Life Ladder',ascending=False)

# %%
df2_sorted
# Out:
#                  Country name  Life Ladder  Log GDP per capita  \
# 37                    Denmark     7.680400           10.879200
# 45                    Finland     7.597154           10.749923
# 133               Switzerland     7.548300           11.095400
# 105                    Norway     7.512400           11.039100
# 99                Netherlands     7.466286           10.886786
# ..                        ...          ...                 ...
# 117                    Rwanda     3.654417            7.451083
# 0                 Afghanistan     3.594667            7.650833
# 139                      Togo     3.555000            7.239222
# 22                    Burundi     3.548200            6.722400
# 26   Central African Republic     3.515000            6.961000
#
#      Social support  Healthy life expectancy at birth  \
# 37         0.957133                         71.169333
# 45         0.949000                         71.180000
# ...

# %%
df2_sorted.reset_index(inplace=True)

# %%
df2_sorted
# Out:
#      index              Country name  Life Ladder  Log GDP per capita  \
# 0       37                   Denmark     7.680400           10.879200
# 1       45                   Finland     7.597154           10.749923
# 2      133               Switzerland     7.548300           11.095400
# 3      105                    Norway     7.512400           11.039100
# 4       99               Netherlands     7.466286           10.886786
# ..     ...                       ...          ...                 ...
# 150    117                    Rwanda     3.654417            7.451083
# 151      0               Afghanistan     3.594667            7.650833
# 152    139                      Togo     3.555000            7.239222
# 153     22                   Burundi     3.548200            6.722400
# 154     26  Central African Republic     3.515000            6.961000
#
#      Social support  Healthy life expectancy at birth  \
# 0          0.957133                         71.169333
# ...

# %% [markdown]
# ## take top 10 and bottom 10 countries

# %%
top=df2_sorted[:10]
bottom=df2_sorted[-10:]

# %%
top
# Out:
#    index Country name  Life Ladder  Log GDP per capita  Social support  \
# 0     37      Denmark     7.680400           10.879200        0.957133
# 1     45      Finland     7.597154           10.749923        0.949000
# 2    133  Switzerland     7.548300           11.095400        0.943600
# 3    105       Norway     7.512400           11.039100        0.950500
# 4     99  Netherlands     7.466286           10.886786        0.933500
# 5     59      Iceland     7.446500           10.860625        0.977500
# 6     25       Canada     7.376333           10.748267        0.935571
# 7    132       Sweden     7.369467           10.819600        0.927933
# 8    100  New Zealand     7.310286           10.583000        0.952929
# 9      6    Australia     7.282071           10.755571        0.947357
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         71.169333                      0.945067    0.170929
# ...

# %%
bottom
# Out:
#      index              Country name  Life Ladder  Log GDP per capita  \
# 145     56                     Haiti     3.954182            7.446727
# 146     30                   Comoros     3.944000            7.991167
# 147    152                     Yemen     3.912250            8.102700
# 148    154                  Zimbabwe     3.882600            7.850333
# 149    137                  Tanzania     3.697333            7.700200
# 150    117                    Rwanda     3.654417            7.451083
# 151      0               Afghanistan     3.594667            7.650833
# 152    139                      Togo     3.555000            7.239222
# 153     22                   Burundi     3.548200            6.722400
# 154     26  Central African Republic     3.515000            6.961000
#
#      Social support  Healthy life expectancy at birth  \
# 145        0.616182                         47.049091
# 146        0.674000                         55.686667
# ...

# %% [markdown]
# # top 10 countries

# %%
import matplotlib.pyplot as plt
plt.bar(top["Country name"], top["Life Ladder"], color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # bottom 10 countries

# %%
import matplotlib.pyplot as plt
plt.bar(bottom["Country name"], bottom["Life Ladder"], color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion
# * to find the top 10 and bottom 10 happy countries we have taken average of the ladder score of each countries from year 2010-2019 and used it represent the result of top and bottom happiest countries

# %% [markdown]
# # Happiest and Unhappiest countries

# %% [markdown]
# ## 2015

# %% [markdown]
# ## select rows with year 2015

# %%
df2015 = df1[df1['year'] == 2015]

# %%
df2015
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 7     Afghanistan  2015        3.983               7.702           0.529
# 19        Albania  2015        4.607               9.403           0.639
# 46      Argentina  2015        6.697              10.083           0.926
# 61        Armenia  2015        4.348               9.334           0.723
# 74      Australia  2015        7.309              10.779           0.952
# ...           ...   ...          ...                 ...             ...
# 1888    Venezuela  2015        5.569               9.001           0.911
# 1903      Vietnam  2015        5.076               8.770           0.849
# 1915        Yemen  2015        2.983               7.858           0.669
# 1928       Zambia  2015        4.843               8.144           0.691
# 1943     Zimbabwe  2015        3.703               7.992           0.736
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ## sort the rows

# %%
df2015s = df2015.sort_values(by='Life Ladder',ascending=False)

# %%
df2015s
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1304       Norway  2015        7.603              11.033           0.947
# 1656  Switzerland  2015        7.572              11.100           0.938
# 458       Denmark  2015        7.514              10.878           0.960
# 727       Iceland  2015        7.498              10.854           0.980
# 558       Finland  2015        7.448              10.716           0.948
# ...           ...   ...          ...                 ...             ...
# 668        Guinea  2015        3.505               7.645           0.579
# 1462       Rwanda  2015        3.483               7.544           0.678
# 1668        Syria  2015        3.462               8.442           0.464
# 1915        Yemen  2015        2.983               7.858           0.669
# 990       Liberia  2015        2.702               7.365           0.638
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ## conclusion

# %% [markdown]
# * happiest country of 2015 is Norway
# * unhappiest country of 2015 is liberia

# %% [markdown]
# # 2016

# %% [markdown]
# ## select rows with year 2016

# %%
df2016 = df1[df1['year'] == 2016]

# %% [markdown]
# ## sort the rows

# %%
df2016s = df2016.sort_values(by='Life Ladder',ascending=False)

# %%
df2016s
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 559                    Finland  2016        7.660              10.740
# 1305                    Norway  2016        7.596              11.035
# 459                    Denmark  2016        7.558              10.903
# 1220               Netherlands  2016        7.541              10.899
# 728                    Iceland  2016        7.510              10.904
# ...                        ...   ...          ...                 ...
# 682                      Haiti  2016        3.352               7.477
# 1463                    Rwanda  2016        3.333               7.576
# 1707                  Tanzania  2016        2.903               7.800
# 1598               South Sudan  2016        2.888                 NaN
# 311   Central African Republic  2016        2.693               6.785
#
#       Social support  Healthy life expectancy at birth  \
# 559            0.954                              71.7
# ...

# %% [markdown]
# # conclusion

# %% [markdown]
# * finland is happiest country
# * central african republic is unhappiest country

# %% [markdown]
# # 2017

# %% [markdown]
# ## select the cells with year 2017

# %%
df2017 = df1[df1['year'] == 2017]

# %% [markdown]
# ## sort the rows

# %%
df2017s = df2017.sort_values(by='Life Ladder',ascending=False)

# %%
df2017s
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 560       Finland  2017        7.788              10.768           0.964
# 460       Denmark  2017        7.594              10.916           0.952
# 1306       Norway  2017        7.579              11.050           0.950
# 729       Iceland  2017        7.476              10.925           0.967
# 1658  Switzerland  2017        7.474              11.115           0.950
# ...           ...   ...          ...                 ...             ...
# 1708     Tanzania  2017        3.347               7.836           0.705
# 1917        Yemen  2017        3.254               7.578           0.790
# 1464       Rwanda  2017        3.108               7.588           0.517
# 1599  South Sudan  2017        2.817                 NaN           0.557
# 9     Afghanistan  2017        2.662               7.697           0.491
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# # conclusion
# * finland is happiest country
# * afghanistan is unhappiest country

# %% [markdown]
# # Ladder score distribution by regional indicator

# %% [markdown]
# ## drop country name and group the records by region indicator

# %%
a = df.drop(columns=['Country name'])
df2 = a.groupby('Regional indicator').mean()

# %%
df2
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              3.554765
# Commonwealth of Independent States      3.037000
# East Asia                               3.380333
# Latin America and Caribbean             3.478050
# Middle East and North Africa            2.789765
# North America and ANZ                   4.698500
# South Asia                              2.011857
# Southeast Asia                          2.977556
# Sub-Saharan Africa                      2.064472
# Western Europe                          4.484905
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.048471
# Commonwealth of Independent States                        0.046750
# East Asia                                                 0.040000
# Latin America and Caribbean                               0.073900
# ...

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#                    Regional indicator  Ladder score  \
# 0          Central and Eastern Europe      3.554765
# 1  Commonwealth of Independent States      3.037000
# 2                           East Asia      3.380333
# 3         Latin America and Caribbean      3.478050
# 4        Middle East and North Africa      2.789765
# 5               North America and ANZ      4.698500
# 6                          South Asia      2.011857
# 7                      Southeast Asia      2.977556
# 8                  Sub-Saharan Africa      2.064472
# 9                      Western Europe      4.484905
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.048471      6.079941      5.889529
# 1                        0.046750      5.558417      5.375250
# 2                        0.040000      5.889500      5.731667
# 3                        0.073900      6.052800      5.763150
# 4                        0.057000      5.331176      5.108059
# ...

# %% [markdown]
# ## plot the graph

# %%
import matplotlib.pyplot as plt
plt.bar(df2["Regional indicator"], df2["Ladder score"], color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # conclusion
# * North america and ANZ has happiest countries
# * South Asia has unhappiest countries

# %% [markdown]
# # Relationship Between features

# %% [markdown]
# # for 2021 report

# %%
df2=df[:]
df2
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         5.412
# 1        Denmark      Western Europe         5.190
# 2    Switzerland      Western Europe         5.141
# 3        Iceland      Western Europe         5.124
# 4    Netherlands      Western Europe         5.034
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         1.082
# 145     Botswana  Sub-Saharan Africa         1.037
# 146       Rwanda  Sub-Saharan Africa         0.985
# 147     Zimbabwe  Sub-Saharan Africa         0.715
# 148  Afghanistan          South Asia         0.093
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# ## label encoding of text columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns_to_encode = ['Country name','Regional indicator']

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply label encoding to selected columns
df2[columns_to_encode] = df2[columns_to_encode].apply(label_encoder.fit_transform)

print(df2)
# Out:
#      Country name  Regional indicator  Ladder score  \
# 0              40                   9         5.412
# 1              33                   9         5.190
# 2             128                   9         5.141
# 3              54                   9         5.124
# 4              96                   9         5.034
# ..            ...                 ...           ...
# 144            74                   8         1.082
# 145            15                   8         1.037
# 146           114                   8         0.985
# 147           148                   8         0.715
# 148             0                   6         0.093
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df3=pd.DataFrame(df2)

# %%
df3
# Out:
#      Country name  Regional indicator  Ladder score  \
# 0              40                   9         5.412
# 1              33                   9         5.190
# 2             128                   9         5.141
# 3              54                   9         5.124
# 4              96                   9         5.034
# ..            ...                 ...           ...
# 144            74                   8         1.082
# 145            15                   8         1.037
# 146           114                   8         0.985
# 147           148                   8         0.715
# 148             0                   6         0.093
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# ## standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
y=scaler.fit_transform(df3)
y
# Out:
# array([[-0.79048394,  1.25406167,  2.15746188, ..., -0.55183758,
#          3.03446416,  1.53529826],
#        [-0.95323064,  1.25406167,  1.95004606, ...,  0.30583027,
#          3.06955896,  0.81679751],
#        [ 1.2554745 ,  1.25406167,  1.90426509, ...,  0.26498894,
#          2.43785246,  0.76267668],
#        ...,
#        [ 0.92998111,  0.93573937, -1.97870855, ...,  0.49982656,
#          3.13974858, -2.49203841],
#        [ 1.72046505,  0.93573937, -2.23097103, ..., -0.21489664,
#         -0.52765865, -2.28675248],
#        [-1.72046505,  0.29909478, -2.81210905, ..., -0.57225825,
#         -1.09794925, -0.99904984]])

# %% [markdown]
# ## finding covariance and explained variance

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(y)
# Out:
# array([[-5.86102593e+00,  2.14490391e+00, -8.72118729e-01, ...,
#          1.49117719e-04,  9.57768767e-05, -7.89799417e-21],
#        [-5.69339745e+00,  2.82481152e+00, -1.33768082e-01, ...,
#          9.56956132e-04, -1.47597667e-04, -1.24398152e-20],
#        [-5.53165931e+00,  2.30282163e+00,  4.35706898e-01, ...,
#          5.15200939e-04,  2.44114084e-04, -8.99785774e-21],
#        ...,
#        [ 3.25939324e+00,  3.93421991e+00,  3.89042906e+00, ...,
#          6.14793812e-04,  2.29958076e-04,  1.99728547e-21],
#        [ 4.69206255e+00, -4.70973778e-01,  3.02085693e+00, ...,
#         -3.68962988e-04, -4.32592430e-04,  1.36242250e-22],
#        [ 8.13064662e+00, -2.21629917e+00,  1.27520687e+00, ...,
#         -8.31537911e-04, -2.88686967e-04, -1.34363184e-21]])

# %%
pca.get_covariance()
# Out:
# array([[ 1.00675676e+00,  4.31549162e-02, -4.75578841e-02,
#         -4.97411132e-02, -5.04611450e-02, -4.46153331e-02,
#         -4.84998242e-04,  1.44779798e-01, -2.13847889e-02,
#          6.48708283e-02,  1.11681676e-01, -1.62435073e-02,
#          6.11855323e-27, -3.92164343e-04,  1.44869321e-01,
#         -2.13435521e-02,  6.47798928e-02,  1.11606418e-01,
#          1.61754129e-02, -1.96326292e-01],
#        [ 4.31549162e-02,  1.00675676e+00, -1.12285541e-01,
#          1.59319927e-01, -1.07837659e-01, -1.16357387e-01,
#         -2.04141695e-01, -2.91466446e-01, -2.61002297e-01,
#         -2.52380004e-02,  2.58660298e-01, -3.08252494e-01,
#         -5.95201729e-26, -2.04106692e-01, -2.91484409e-01,
#         -2.60855601e-01, -2.51886365e-02,  2.58862856e-01,
#          3.08229083e-01,  6.67119929e-02],
#        [-4.75578841e-02, -1.12285541e-01,  1.00675676e+00,
#         -4.73967874e-01,  1.00609948e+00,  1.00614895e+00,
# ...

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([4.79446785e-01, 1.49702473e-01, 8.93584291e-02, 8.22656643e-02,
#        5.52246148e-02, 4.91599823e-02, 3.20057628e-02, 2.70219028e-02,
#        2.35433793e-02, 1.22698836e-02, 3.58571280e-07, 2.65075360e-07,
#        2.16033844e-07, 1.77424287e-07, 4.33480099e-08, 2.91086982e-08,
#        1.87919411e-08, 1.24417324e-08, 3.22795527e-09, 3.04232652e-42])

# %% [markdown]
# ## plot the graph

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(20, 10))

    plt.bar(range(20), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel("Explained variance ratio")
    plt.xlabel("Principal components")
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# # for 2010 to 2020 report

# %%
df2=m[:]
df2
# Out:
#     Country name  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan     3.594667            7.650833        0.508417
# 1        Albania     5.019385            9.384385        0.716231
# 2        Algeria     5.389875            9.328875        0.803571
# 3         Angola     4.420250            8.990000        0.738250
# 4      Argentina     6.310133           10.033800        0.904400
# ..           ...          ...                 ...             ...
# 150    Venezuela     6.019867            9.480083        0.910133
# 151      Vietnam     5.305857            8.655286        0.829231
# 152        Yemen     3.912250            8.102700        0.739833
# 153       Zambia     4.551714            8.066857        0.737714
# 154     Zimbabwe     3.882600            7.850333        0.799400
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                           52.266667                      0.518167
# ...

# %% [markdown]
# ## label encoding of text column

# %%
columns_to_encode = ['Country name']

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply label encoding to selected columns
df2[columns_to_encode] = df2[columns_to_encode].apply(label_encoder.fit_transform)

print(df2)
# Out:
#      Country name  Life Ladder  Log GDP per capita  Social support  \
# 0               0     3.594667            7.650833        0.508417
# 1               1     5.019385            9.384385        0.716231
# 2               2     5.389875            9.328875        0.803571
# 3               3     4.420250            8.990000        0.738250
# 4               4     6.310133           10.033800        0.904400
# ..            ...          ...                 ...             ...
# 150           150     6.019867            9.480083        0.910133
# 151           151     5.305857            8.655286        0.829231
# 152           152     3.912250            8.102700        0.739833
# 153           153     4.551714            8.066857        0.737714
# 154           154     3.882600            7.850333        0.799400
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                           52.266667                      0.518167
# ...

# %%
df3=pd.DataFrame(df2)

# %%
df3
# Out:
#      Country name  Life Ladder  Log GDP per capita  Social support  \
# 0               0     3.594667            7.650833        0.508417
# 1               1     5.019385            9.384385        0.716231
# 2               2     5.389875            9.328875        0.803571
# 3               3     4.420250            8.990000        0.738250
# 4               4     6.310133           10.033800        0.904400
# ..            ...          ...                 ...             ...
# 150           150     6.019867            9.480083        0.910133
# 151           151     5.305857            8.655286        0.829231
# 152           152     3.912250            8.102700        0.739833
# 153           153     4.551714            8.066857        0.737714
# 154           154     3.882600            7.850333        0.799400
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                           52.266667                      0.518167
# ...

# %% [markdown]
# ## standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
y=scaler.fit_transform(df3)
y
# Out:
# array([[-1.7209121 , -1.69489186, -1.37262375, ...,  0.57980259,
#         -1.64772756,  0.78495366],
#        [-1.69856259, -0.36160894,  0.08794212, ...,  0.72692727,
#         -0.5622099 ,  0.38715178],
#        [-1.67621309, -0.01489575,  0.0411737 , ..., -0.2805003 ,
#         -1.03094757, -0.15180044],
#        ...,
#        [ 1.67621309, -1.39769028, -0.99191333, ...,  0.47438254,
#         -1.83521884,  0.30476733],
#        [ 1.69856259, -0.79926529, -1.02211195, ...,  0.49804827,
#          0.12717358,  0.31605561],
#        [ 1.7209121 , -1.42543741, -1.20453937, ...,  0.58469709,
#          0.09714549, -0.70447494]])

# %% [markdown]
# ## finding covariance and explained variance

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(y)
# Out:
# array([[ 4.31043354,  0.48074233, -1.64500096, ...,  0.52978525,
#          0.32078253,  0.07291927],
#        [ 1.05474002, -1.24413423, -1.41104445, ...,  0.57057911,
#         -0.17051675,  0.17599746],
#        [ 0.96947744, -1.73356664, -1.06076835, ...,  0.15614063,
#         -0.35315808, -0.17554325],
#        ...,
#        [ 2.7308036 , -0.314463  ,  1.84355526, ..., -0.52516402,
#         -0.10001005, -0.04618534],
#        [ 1.48555063,  1.29190754,  1.55847506, ..., -0.1662084 ,
#          0.28702435, -0.07468271],
#        [ 2.03906302,  0.74169533,  2.46174207, ..., -0.10460399,
#         -0.12577023,  0.24182086]])

# %%
pca.get_covariance()
# Out:
# array([[ 1.00649351,  0.02799023,  0.04859584,  0.16711632,  0.02494159,
#          0.09472006,  0.06308341, -0.06418689,  0.08147799, -0.16019647],
#        [ 0.02799023,  1.00649351,  0.84821995,  0.78565845,  0.81974051,
#          0.62202662,  0.19918522, -0.46928331,  0.59026313, -0.3667334 ],
#        [ 0.04859584,  0.84821995,  1.00649351,  0.7633146 ,  0.86399788,
#          0.44242446, -0.00675866, -0.37493702,  0.36043503, -0.28564294],
#        [ 0.16711632,  0.78565845,  0.7633146 ,  1.00649351,  0.69557314,
#          0.49891032,  0.06909755, -0.24592906,  0.52462061, -0.46721908],
#        [ 0.02494159,  0.81974051,  0.86399788,  0.69557314,  1.00649351,
#          0.44305033,  0.03358854, -0.32978265,  0.35291642, -0.2504415 ],
#        [ 0.09472006,  0.62202662,  0.44242446,  0.49891032,  0.44305033,
#          1.00649351,  0.39898669, -0.5257419 ,  0.70998448, -0.38698801],
#        [ 0.06308341,  0.19918522, -0.00675866,  0.06909755,  0.03358854,
# ...

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.47079041, 0.15352056, 0.10599335, 0.08215793, 0.06987169,
#        0.04658139, 0.02472786, 0.02301706, 0.01245419, 0.01088557])

# %% [markdown]
# ## plotting graph

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(10, 7))

    plt.bar(range(10), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel("Explained variance ratio")
    plt.xlabel("Principal components")
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# # generosity in 2021

# %% [markdown]
# ## sort via generosity

# %%
a = df.sort_values(by='Generosity',ascending=False)
a
# Out:
#     Country name                  Regional indicator  Ladder score  \
# 81     Indonesia                      Southeast Asia         2.915
# 125      Myanmar                      Southeast Asia         1.996
# 97        Gambia                  Sub-Saharan Africa         2.621
# 142        Haiti         Latin America and Caribbean         1.185
# 41    Uzbekistan  Commonwealth of Independent States         3.749
# ..           ...                                 ...           ...
# 107      Georgia  Commonwealth of Independent States         2.461
# 57      Portugal                      Western Europe         3.499
# 145     Botswana                  Sub-Saharan Africa         1.037
# 55         Japan                           East Asia         3.510
# 67        Greece                      Western Europe         3.293
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 81                            0.056         5.454         5.235
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# * Indonesia is the most generous country
# * Greece is the least generous country

# %% [markdown]
# # Relationships

# %%
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         5.412
# 1        Denmark      Western Europe         5.190
# 2    Switzerland      Western Europe         5.141
# 3        Iceland      Western Europe         5.124
# 4    Netherlands      Western Europe         5.034
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         1.082
# 145     Botswana  Sub-Saharan Africa         1.037
# 146       Rwanda  Sub-Saharan Africa         0.985
# 147     Zimbabwe  Sub-Saharan Africa         0.715
# 148  Afghanistan          South Asia         0.093
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
m
# Out:
#     Country name  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan     3.594667            7.650833        0.508417
# 1        Albania     5.019385            9.384385        0.716231
# 2        Algeria     5.389875            9.328875        0.803571
# 3         Angola     4.420250            8.990000        0.738250
# 4      Argentina     6.310133           10.033800        0.904400
# ..           ...          ...                 ...             ...
# 150    Venezuela     6.019867            9.480083        0.910133
# 151      Vietnam     5.305857            8.655286        0.829231
# 152        Yemen     3.912250            8.102700        0.739833
# 153       Zambia     4.551714            8.066857        0.737714
# 154     Zimbabwe     3.882600            7.850333        0.799400
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                           52.266667                      0.518167
# ...

# %%
df['Ladder score'].max()
# Out:
# 5.411999999999999

# %%
df['Ladder score'].min()
# Out:
# 0.09299999999999997

# %% [markdown]
# # happiness and gdp

# %% [markdown]
# ## divide ladder score into ranges

# %%
a=df[["Ladder score","Logged GDP per capita"]]
a
# Out:
#      Ladder score  Logged GDP per capita
# 0           5.412                 10.775
# 1           5.190                 10.933
# 2           5.141                 11.117
# 3           5.124                 10.878
# 4           5.034                 10.932
# ..            ...                    ...
# 144         1.082                  7.926
# 145         1.037                  9.782
# 146         0.985                  7.676
# 147         0.715                  7.943
# 148         0.093                  7.695
#
# [149 rows x 2 columns]

# %%
b=a.sort_values(by="Ladder score")
b
# Out:
#      Ladder score  Logged GDP per capita
# 148         0.093                  7.695
# 147         0.715                  7.943
# 146         0.985                  7.676
# 145         1.037                  9.782
# 144         1.082                  7.926
# ..            ...                    ...
# 4           5.034                 10.932
# 3           5.124                 10.878
# 2           5.141                 11.117
# 1           5.190                 10.933
# 0           5.412                 10.775
#
# [149 rows x 2 columns]

# %%
bin_ranges=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5]

# %%
bins = pd.cut(b["Ladder score"], bins=bin_ranges, labels=['0-0.5', '0.5-1', '1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5','5-5.5'])

# Create a DataFrame
e = pd.DataFrame({'Ladder score': b['Ladder score'], 'bin': bins,'Logged GDP per capita':b['Logged GDP per capita']})
e
# Out:
#      Ladder score    bin  Logged GDP per capita
# 148         0.093  0-0.5                  7.695
# 147         0.715  0.5-1                  7.943
# 146         0.985  0.5-1                  7.676
# 145         1.037  1-1.5                  9.782
# 144         1.082  1-1.5                  7.926
# ..            ...    ...                    ...
# 4           5.034  5-5.5                 10.932
# 3           5.124  5-5.5                 10.878
# 2           5.141  5-5.5                 11.117
# 1           5.190  5-5.5                 10.933
# 0           5.412  5-5.5                 10.775
#
# [149 rows x 3 columns]

# %%
f=e.groupby(by='bin')['Logged GDP per capita'].mean()
g=pd.DataFrame(f)
g.reset_index(inplace=True)
g
# Out:
#       bin  Logged GDP per capita
# 0   0-0.5               7.695000
# 1   0.5-1               7.809500
# 2   1-1.5               7.824556
# 3   1.5-2               8.346583
# 4   2-2.5               8.705150
# 5   2.5-3               8.944333
# 6   3-3.5               9.679636
# 7   3.5-4              10.014520
# 8   4-4.5              10.525917
# 9   4.5-5              10.831714
# 10  5-5.5              10.927000

# %% [markdown]
# ## plot the graph

# %%
plt.plot(g["bin"], g["Logged GDP per capita"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # conclusion
# * as gdp increases happiness increases

# %% [markdown]
# # happiness and freedom

# %% [markdown]
# ## divide ladder score into ranges

# %%
a=df[["Ladder score","Freedom to make life choices"]]
a
# Out:
#      Ladder score  Freedom to make life choices
# 0           5.412                         0.949
# 1           5.190                         0.946
# 2           5.141                         0.919
# 3           5.124                         0.955
# 4           5.034                         0.913
# ..            ...                           ...
# 144         1.082                         0.715
# 145         1.037                         0.824
# 146         0.985                         0.897
# 147         0.715                         0.677
# 148         0.093                         0.382
#
# [149 rows x 2 columns]

# %%
b=a.sort_values(by="Ladder score")
b
# Out:
#      Ladder score  Freedom to make life choices
# 148         0.093                         0.382
# 147         0.715                         0.677
# 146         0.985                         0.897
# 145         1.037                         0.824
# 144         1.082                         0.715
# ..            ...                           ...
# 4           5.034                         0.913
# 3           5.124                         0.955
# 2           5.141                         0.919
# 1           5.190                         0.946
# 0           5.412                         0.949
#
# [149 rows x 2 columns]

# %%
bin_ranges=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5]

# %%
bins = pd.cut(b["Ladder score"], bins=bin_ranges, labels=['0-0.5', '0.5-1', '1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5','5-5.5'])

# Create a DataFrame
e = pd.DataFrame({'Ladder score': b['Ladder score'], 'bin': bins,'Freedom to make life choices':b['Freedom to make life choices']})
e
# Out:
#      Ladder score    bin  Freedom to make life choices
# 148         0.093  0-0.5                         0.382
# 147         0.715  0.5-1                         0.677
# 146         0.985  0.5-1                         0.897
# 145         1.037  1-1.5                         0.824
# 144         1.082  1-1.5                         0.715
# ..            ...    ...                           ...
# 4           5.034  5-5.5                         0.913
# 3           5.124  5-5.5                         0.955
# 2           5.141  5-5.5                         0.919
# 1           5.190  5-5.5                         0.946
# 0           5.412  5-5.5                         0.949
#
# [149 rows x 3 columns]

# %%
f=e.groupby(by='bin')['Freedom to make life choices'].mean()
g=pd.DataFrame(f)
g.reset_index(inplace=True)
g
# Out:
#       bin  Freedom to make life choices
# 0   0-0.5                      0.382000
# 1   0.5-1                      0.787000
# 2   1-1.5                      0.731444
# 3   1.5-2                      0.688417
# 4   2-2.5                      0.704550
# 5   2.5-3                      0.789741
# 6   3-3.5                      0.789455
# 7   3.5-4                      0.836360
# 8   4-4.5                      0.854583
# 9   4.5-5                      0.894286
# 10  5-5.5                      0.936400

# %% [markdown]
# ## plot the graph

# %%
plt.plot(g["bin"], g["Freedom to make life choices"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # conclusion
# * as freedom increases happiness increases

# %% [markdown]
# # happiness vs corruption

# %% [markdown]
# ## divide ladder score into ranges

# %%
a=df[["Ladder score","Perceptions of corruption"]]
a
# Out:
#      Ladder score  Perceptions of corruption
# 0           5.412                      0.186
# 1           5.190                      0.179
# 2           5.141                      0.292
# 3           5.124                      0.673
# 4           5.034                      0.338
# ..            ...                        ...
# 144         1.082                      0.915
# 145         1.037                      0.801
# 146         0.985                      0.167
# 147         0.715                      0.821
# 148         0.093                      0.924
#
# [149 rows x 2 columns]

# %%
b=a.sort_values(by="Ladder score")
b
# Out:
#      Ladder score  Perceptions of corruption
# 148         0.093                      0.924
# 147         0.715                      0.821
# 146         0.985                      0.167
# 145         1.037                      0.801
# 144         1.082                      0.915
# ..            ...                        ...
# 4           5.034                      0.338
# 3           5.124                      0.673
# 2           5.141                      0.292
# 1           5.190                      0.179
# 0           5.412                      0.186
#
# [149 rows x 2 columns]

# %%
bin_ranges=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5]

# %%
bins = pd.cut(b["Ladder score"], bins=bin_ranges, labels=['0-0.5', '0.5-1', '1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5','5-5.5'])

# Create a DataFrame
e = pd.DataFrame({'Ladder score': b['Ladder score'], 'bin': bins,'Perceptions of corruption':b['Perceptions of corruption']})
e
# Out:
#      Ladder score    bin  Perceptions of corruption
# 148         0.093  0-0.5                      0.924
# 147         0.715  0.5-1                      0.821
# 146         0.985  0.5-1                      0.167
# 145         1.037  1-1.5                      0.801
# 144         1.082  1-1.5                      0.915
# ..            ...    ...                        ...
# 4           5.034  5-5.5                      0.338
# 3           5.124  5-5.5                      0.673
# 2           5.141  5-5.5                      0.292
# 1           5.190  5-5.5                      0.179
# 0           5.412  5-5.5                      0.186
#
# [149 rows x 3 columns]

# %%
f=e.groupby(by='bin')['Perceptions of corruption'].mean()
g=pd.DataFrame(f)
g.reset_index(inplace=True)
g
# Out:
#       bin  Perceptions of corruption
# 0   0-0.5                   0.924000
# 1   0.5-1                   0.494000
# 2   1-1.5                   0.754444
# 3   1.5-2                   0.767417
# 4   2-2.5                   0.816700
# 5   2.5-3                   0.774148
# 6   3-3.5                   0.791318
# 7   3.5-4                   0.756600
# 8   4-4.5                   0.697333
# 9   4.5-5                   0.491643
# 10  5-5.5                   0.333600

# %% [markdown]
# ## plot the graph

# %%
plt.plot(g["bin"], g["Perceptions of corruption"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # conclusion
# * as corruption decreases happiness increases
